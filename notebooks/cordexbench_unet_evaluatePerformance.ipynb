# %% [markdown]
# important capabilities:
# * transferability
# * extremes
# * multivariate coherence
# * tempoeral coherence
# * generative weather (from lowres GCM)
#
# applications
# * supplementing RCMs
# * event attribution
# * high res extremes
# * montly forecasts
# * probabilistic projects
#
# things to test
# - multivariable coherence
# - global transferability
# - temporal coherence
# -
